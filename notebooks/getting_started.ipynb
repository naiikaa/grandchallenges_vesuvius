# %%
from vesuvius import list_files
from vesuvius import cubes

# %%
files = list_files()

# %%
cubes = cubes()

# %%
import vesuvius
import matplotlib.pyplot as plt

scroll = vesuvius.Volume("Scroll1")
img = scroll[1000,2000:2200,3000:3200]

plt.imshow(img)

# %%
scroll.shape()
# Out:
# (14376, 7888, 8096)

# %%
#gif from the 1000x1000 cutout of the scroll
import imageio
import os
import numpy as np
import tqdm

def make_gif():
    img = scroll[0:1000, 2000:2500, 4000:4500]
    # Save the images as a GIF
    imageio.mimsave('scroll_animation.gif', img)

make_gif()
